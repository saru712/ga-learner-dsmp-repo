# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.metrics import mean_absolute_error,mean_squared_error, r2_score,make_scorer
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Load the dataset
#
# - Load the train data and using all your knowledge of pandas try to explore the different statistical properties like correlation of the dataset.

# %%
# # Code starts here

# train = pd.read_csv("train.csv")

# train.head()
# # train.info()

# # train.isnull().sum()
# # train.describe()
# train.columns
# # Code ends here.

# %%
# train.head()

# %%
# train.corr()

# %% [markdown]
# ## Model building
#
# - Separate the features and target and then split the train data into train and validation set.
# - Apply different models of your choice and  then predict on the validation data and find the `accuracy_score` for this prediction.
# - Try improving upon the `accuracy_score` using different regularization techniques.

# %%
# Code starts here

# Split into features and target
X = train.drop(['Price'],axis=1)
y = train['Price']

# Separate into train and test data
X_train, X_test, y_train, y_test = train_test_split(X,y,random_state=30,test_size=0.08)

# print(X_train.head(2))
# print(y_train.head(2))

# Instantiate linear regression
regressor = LinearRegression()

# fit the model on training data
regressor.fit(X_train,y_train)


# make prediction
y_pred = regressor.predict(X_test)

# # calculate the mean_absolute_error
# mae = mean_absolute_error(y_test, y_pred)
# print(mae)

# calculate the r2 score
r2 = r2_score(y_test, y_pred)
print(r2)   

# Code ends here.
# Out:
# 0.6741242167339545

# %%
X_train.corr()

#Building area with rooms and bathroom with rooms are highly correlated
# Out:
#                      Id     Rooms      Type    Method   SellerG  Distance  \
# Id             1.000000  0.070876 -0.082628  0.015580  0.037338  0.299131
# Rooms          0.070876  1.000000 -0.591691 -0.055509 -0.037077  0.292686
# Type          -0.082628 -0.591691  1.000000  0.087482  0.030624 -0.247787
# Method         0.015580 -0.055509  0.087482  1.000000 -0.005473 -0.064063
# SellerG        0.037338 -0.037077  0.030624 -0.005473  1.000000  0.022834
# Distance       0.299131  0.292686 -0.247787 -0.064063  0.022834  1.000000
# Postcode       0.083149  0.049507  0.020019 -0.034514  0.002431  0.424283
# Bathroom       0.006651  0.608581 -0.276986 -0.019471 -0.041029  0.115608
# Car            0.083560  0.416997 -0.283570 -0.021932  0.001629  0.262489
# Landsize       0.076063  0.085562 -0.036950 -0.022294 -0.027065  0.057948
# BuildingArea  -0.020497  0.590720 -0.383268 -0.049925 -0.046877  0.144757
# YearBuilt      0.108219 -0.058786  0.300430  0.016324 -0.004458  0.251527
# CouncilArea   -0.200123 -0.208565  0.160088  0.014403 -0.003018 -0.281268
# Longtitude     0.021170  0.098117  0.002807 -0.060196 -0.064592  0.202268
# Regionname    -0.105660 -0.009112  0.056108  0.044356  0.023506 -0.084918
# Propertycount  0.017466 -0.110457  0.118989 -0.020248  0.066235 -0.071693
#
#                Postcode  Bathroom       Car  Landsize  BuildingArea  \
# Id             0.083149  0.006651  0.083560  0.076063     -0.020497
# Rooms          0.049507  0.608581  0.416997  0.085562      0.590720
# Type           0.020019 -0.276986 -0.283570 -0.036950     -0.383268
# Method        -0.034514 -0.019471 -0.021932 -0.022294     -0.049925
# SellerG        0.002431 -0.041029  0.001629 -0.027065     -0.046877
# Distance       0.424283  0.115608  0.262489  0.057948      0.144757
# Postcode       1.000000  0.084786  0.025533  0.030302      0.056426
# Bathroom       0.084786  1.000000  0.326649  0.078819      0.518125
# Car            0.025533  0.326649  1.000000  0.108551      0.314951
# Landsize       0.030302  0.078819  0.108551  1.000000      0.076709
# BuildingArea   0.056426  0.518125  0.314951  0.076709      1.000000
# YearBuilt      0.030973  0.156432  0.108820  0.034860      0.012727
# CouncilArea   -0.062960 -0.105259 -0.172679 -0.045376     -0.165627
# Longtitude     0.418143  0.109964  0.049759  0.037868      0.103751
# Regionname     0.008039  0.039258  0.009184 -0.012948      0.035599
# Propertycount  0.059554 -0.058690 -0.035141 -0.018068     -0.072261
#
#                YearBuilt  CouncilArea  Longtitude  Regionname  Propertycount
# Id              0.108219    -0.200123    0.021170   -0.105660       0.017466
# Rooms          -0.058786    -0.208565    0.098117   -0.009112      -0.110457
# Type            0.300430     0.160088    0.002807    0.056108       0.118989
# Method          0.016324     0.014403   -0.060196    0.044356      -0.020248
# SellerG        -0.004458    -0.003018   -0.064592    0.023506       0.066235
# Distance        0.251527    -0.281268    0.202268   -0.084918      -0.071693
# Postcode        0.030973    -0.062960    0.418143    0.008039       0.059554
# Bathroom        0.156432    -0.105259    0.109964    0.039258      -0.058690
# Car             0.108820    -0.172679    0.049759    0.009184      -0.035141
# Landsize        0.034860    -0.045376    0.037868   -0.012948      -0.018068
# BuildingArea    0.012727    -0.165627    0.103751    0.035599      -0.072261
# YearBuilt       1.000000    -0.066568   -0.007569   -0.012465       0.020075
# CouncilArea    -0.066568     1.000000   -0.154728   -0.044848       0.022083
# Longtitude     -0.007569    -0.154728    1.000000   -0.480561       0.049052
# Regionname     -0.012465    -0.044848   -0.480561    1.000000      -0.140861
# Propertycount   0.020075     0.022083    0.049052   -0.140861       1.000000

# %%
# X_train.Bathroom = X_train.Bathroom**3

# X_test.Bathroom =X_test.Bathroom**3

lasso=Lasso()

lasso.fit(X_train,y_train)

lasso_pred=lasso.predict(X_test)


# calculate the mean_absolute_error
mae_lasso = np.sqrt(mean_absolute_error(y_test, lasso_pred))
print(mae_lasso)

# calculate the r2 score
r2_lasso = r2_score(y_test, lasso_pred)
print(r2_lasso)
# Out:
# 508.5743627632765
# 0.6741230974428124

# %%
ridge=Ridge()

ridge.fit(X_train,y_train)

ridge_pred=ridge.predict(X_test)


# calculate the mean_absolute_error
mae_ridge = mean_absolute_error(y_test, lasso_pred)
print(mae_ridge)

# calculate the r2 score
r2_ridge = r2_score(y_test, ridge_pred)
print(r2_ridge)
# Out:
# 258647.88246007275
# 0.6736237272699098

# %%
scorer =make_scorer(mean_squared_error,greater_is_better=False)

rmse_L1= -np.mean(cross_val_score(lasso,X_train,y_train,scoring=scorer,cv=10))

rmse_L2= -np.mean(cross_val_score(ridge,X_train,y_train,scoring=scorer,cv=10))

# print(rmse_L1,rmse_L2)


Model_1 =lasso if rmse_L1< rmse_L2 else ridge

print(Model_1)


Model_1.fit(X_train,y_train)

pred=Model_1.predict(X_test)

Error=r2_score(y_test, pred)

print(Error,rmse_L1,rmse_L2)
# Out:
# Lasso()
# 0.6741230974428124 183897003797.74554 183931766964.45917

# %%
model= make_pipeline(PolynomialFeatures(3),LinearRegression())

model.fit(X_train,y_train)

y_pred_m= model.predict(X_test)


# # calculate the mean_absolute_error
# mae_ridge = mean_absolute_error(y_test, lasso_pred)
# print(mae_ridge)

# calculate the r2 score
r2_poly= r2_score(y_test, y_pred_m)
print(r2_poly)
# Out:
# 0.6685918907919439

# %%
# Code starts here
poly = PolynomialFeatures(3)
X_train_2 = poly.fit_transform(X_train)
X_test_2 = poly.transform(X_test)

model_p = LinearRegression()
model_p.fit(X_train_2, y_train)

y_pred_2 = model_p.predict(X_test_2)

r2_p = r2_score(y_test,y_pred_2)
print("r2", r2_p)

# mae = mean_absolute_error(y_test, y_pred_2)
# print("mae", mae)
# Code ends here
# Out:
# r2 0.6685918907919439

# %%
X_train.shape
# Out:
# (4398, 16)

# %% [markdown]
# ### Prediction on the test data and creating the sample submission file.
#
# - Load the test data and store the `Id` column in a separate variable.
# - Perform the same operations on the test data that you have performed on the train data.
# - Create the submission file as a `csv` file consisting of the `Id` column from the test data and your prediction as the second column.

# %%
# Code Starts here
# Prediction on test data

# Read the test data
test = pd.read_csv('test.csv')

# Storing the id from the test file
id_ = test['Id']

# Code ends here.

# %%
test.head()
# Out:
#      Id  Rooms  Type  Method  SellerG  Distance  Postcode  Bathroom  Car  \
# 0  5067      4     0       1       32      27.0      3196         2    2
# 1  3722      4     0       1       28      12.4      3060         2    2
# 2  6820      5     0       1       16      12.4      3107         3    2
# 3  3103      2     2       1      196       3.3      3141         1    1
# 4  2820      3     0       1       16      11.2      3073         2    1
#
#    Landsize  BuildingArea  YearBuilt  CouncilArea  Longtitude  Regionname  \
# 0       536         202.0       1985           12   145.13286           4
# 1       567         116.0       1950           23   144.97030           2
# 2       717         310.0       1963           -1   145.11320           0
# 3         0          61.0       1965           26   144.98860           5
# 4       618         149.0       1965            6   145.02120           2
#
#    Propertycount
# 0           2076
# 1           5070
# 2           5420
# 3          14887
# 4          21650

# %%
test_poly.shape
# Out:
# (2049, 969)

# %%
# # Applying rfe on test data
# test_poly = poly.transform(test)

# #Predict on the test data
# y_pred_test = model.predict(test_poly)
# y_pred_test = y_pred_test.flatten()
# print(y_pred_test_1)


# model.fit(X_train,y_train)

y_pred_test_2= model.predict(test)
# Create a sample submission file
sample_submission = pd.DataFrame({'Id':id_,'Price':y_pred_test_2})

# Convert the sample submission file into a csv file
sample_submission.to_csv('sample_submission.csv',index=False)
